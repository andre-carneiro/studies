# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#CLUSTER-ANALYSIS-IN-PYTHON" data-toc-modified-id="CLUSTER-ANALYSIS-IN-PYTHON-1"><span class="toc-item-num">1&nbsp;&nbsp;</span><strong>CLUSTER ANALYSIS IN PYTHON</strong></a></span><ul class="toc-item"><li><span><a href="#Introduction-to-Clustering" data-toc-modified-id="Introduction-to-Clustering-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Introduction to Clustering</a></span><ul class="toc-item"><li><span><a href="#Unsupervised-learning:-basics" data-toc-modified-id="Unsupervised-learning:-basics-1.1.1"><span class="toc-item-num">1.1.1&nbsp;&nbsp;</span>Unsupervised learning: basics</a></span></li><li><span><a href="#Basics-of-cluster-analysis" data-toc-modified-id="Basics-of-cluster-analysis-1.1.2"><span class="toc-item-num">1.1.2&nbsp;&nbsp;</span>Basics of cluster analysis</a></span></li><li><span><a href="#Data-preparation-for-cluster-analysis" data-toc-modified-id="Data-preparation-for-cluster-analysis-1.1.3"><span class="toc-item-num">1.1.3&nbsp;&nbsp;</span>Data preparation for cluster analysis</a></span></li></ul></li><li><span><a href="#Hierarchical-Clustering" data-toc-modified-id="Hierarchical-Clustering-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Hierarchical Clustering</a></span><ul class="toc-item"><li><span><a href="#Basics-of-hierarchical-clustering" data-toc-modified-id="Basics-of-hierarchical-clustering-1.2.1"><span class="toc-item-num">1.2.1&nbsp;&nbsp;</span>Basics of hierarchical clustering</a></span></li><li><span><a href="#Visualize-clusters" data-toc-modified-id="Visualize-clusters-1.2.2"><span class="toc-item-num">1.2.2&nbsp;&nbsp;</span>Visualize clusters</a></span></li><li><span><a href="#How-many-clusters?" data-toc-modified-id="How-many-clusters?-1.2.3"><span class="toc-item-num">1.2.3&nbsp;&nbsp;</span>How many clusters?</a></span></li><li><span><a href="#Limitations-of-hierarchical-clustering" data-toc-modified-id="Limitations-of-hierarchical-clustering-1.2.4"><span class="toc-item-num">1.2.4&nbsp;&nbsp;</span>Limitations of hierarchical clustering</a></span></li></ul></li><li><span><a href="#K-Means-clustering" data-toc-modified-id="K-Means-clustering-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>K-Means clustering</a></span><ul class="toc-item"><li><span><a href="#Basics-of-k-means-clustering" data-toc-modified-id="Basics-of-k-means-clustering-1.3.1"><span class="toc-item-num">1.3.1&nbsp;&nbsp;</span>Basics of k-means clustering</a></span></li><li><span><a href="#How-many-clusters?" data-toc-modified-id="How-many-clusters?-1.3.2"><span class="toc-item-num">1.3.2&nbsp;&nbsp;</span>How many clusters?</a></span></li><li><span><a href="#Limitation-of-k-means-clustering" data-toc-modified-id="Limitation-of-k-means-clustering-1.3.3"><span class="toc-item-num">1.3.3&nbsp;&nbsp;</span>Limitation of k-means clustering</a></span></li></ul></li><li><span><a href="#Clustering-in-Real-World" data-toc-modified-id="Clustering-in-Real-World-1.4"><span class="toc-item-num">1.4&nbsp;&nbsp;</span>Clustering in Real World</a></span><ul class="toc-item"><li><span><a href="#Dominant-colors-in-image" data-toc-modified-id="Dominant-colors-in-image-1.4.1"><span class="toc-item-num">1.4.1&nbsp;&nbsp;</span>Dominant colors in image</a></span></li><li><span><a href="#Document-clustering" data-toc-modified-id="Document-clustering-1.4.2"><span class="toc-item-num">1.4.2&nbsp;&nbsp;</span>Document clustering</a></span></li><li><span><a href="#Clustering-with-multiple-features" data-toc-modified-id="Clustering-with-multiple-features-1.4.3"><span class="toc-item-num">1.4.3&nbsp;&nbsp;</span>Clustering with multiple features</a></span></li><li><span><a href="#Farewell!" data-toc-modified-id="Farewell!-1.4.4"><span class="toc-item-num">1.4.4&nbsp;&nbsp;</span>Farewell!</a></span></li></ul></li></ul></li></ul></div>

# %% [markdown]
# # **CLUSTER ANALYSIS IN PYTHON**

# %% [markdown]
# ## Introduction to Clustering

# %% [markdown]
# ### Unsupervised learning: basics

# %% [markdown]
# Everyday example: Google news
# - How does Google News classify articles?
# - Unsupervised Learning Algorithm: Clustering
# - Match frequent terms in articles to find similarity

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Labeled and unlabeled data
# - Data with no labels
#     - Point 1: (1, 2)
#     - Point 2: (2, 2)
#     - Point 3: (3, 1)
#
# - Data with labels
#     - Point 1: (1, 2), Label: Danger Zone
#     - Point 2: (2, 2), Label: Normal Zone
#     - Point 3: (3, 1), Label: Normal Zone

# %% [markdown]
# What is unsupervised learning?
# - A group of machine learning algorithms that nd paerns in data
# - Data for algorithms has not been labeled, classied or characterized
# - The objective of the algorithm is to interpret any structure in the data
# - Common unsupervised learning algorithms: clustering, neural networks, anomaly detection

# %% [markdown]
# What is clustering?
# - The process of grouping items with similar characteristics
# - Items in groups similar to each other than in other groups
# - Example: distance between points on a 2D plane

# %% [markdown]
# Plotting data for clustering - Pokemon sightings

# %%
from matplotlib import pyplot as plt

x_coordinates = [80, 93, 86, 98, 86, 9, 15, 3, 10, 20, 44, 56, 49, 62, 44]
y_coordinates = [87, 96, 95, 92, 92, 57, 49, 47, 59, 55, 25, 2, 10, 24, 10]

plt.scatter(x_coordinates, y_coordinates)
plt.show()

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
#Example
# Import plotting class from matplotlib library
from matplotlib import pyplot as plt

# Create a scatter plot
plt.scatter(x, y)

# Display the scatter plot
plt.show()

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Basics of cluster analysis

# %% [markdown]
# What is a cluster?
# - A group of items with similar characteristics
# - Google News: articles where similar words and word associations appear together
# - Customer Segments

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Clustering algorithms
# - Hierarchical clustering
# - K means clustering
# - Other clustering algorithms: DBSCAN, Gaussian Methods

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Hierarchical clustering in SciPy

# %%
from scipy.cluster.hierarchy import linkage, fcluster
from matplotlib import pyplot as plt
import seaborn as sns, pandas as pd

x_coordinates = [80.1, 93.1, 86.6, 98.5, 86.4, 9.5, 15.2, 3.4,
                 10.4, 20.3, 44.2, 56.8, 49.2, 62.5, 44.0]
y_coordinates = [87.2, 96.1, 95.6, 92.4, 92.4, 57.7, 49.4,
                 47.3, 59.1, 55.5, 25.6, 2.1, 10.9, 24.1, 10.3]

df = pd.DataFrame({'x_coordinate': x_coordinates,
                   'y_coordinate': y_coordinates})

Z = linkage(df,'ward')
df['cluster_labels'] = fcluster(Z, 3, criterion='maxclust')

sns.scatterplot(x='x_coordinate', y='y_coordinate',hue='cluster_labels', data = df)
plt.show()

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# K-means clustering in SciPy

# %%
from scipy.cluster.vq import kmeans, vq
from matplotlib import pyplot as plt
import seaborn as sns, pandas as pd

import random
random.seed((1000,2000))

x_coordinates = [80.1, 93.1, 86.6, 98.5, 86.4, 9.5, 15.2, 3.4,
                 10.4, 20.3, 44.2, 56.8, 49.2, 62.5, 44.0]
y_coordinates = [87.2, 96.1, 95.6, 92.4, 92.4, 57.7, 49.4,
                 47.3, 59.1, 55.5, 25.6, 2.1, 10.9, 24.1, 10.3]

df = pd.DataFrame({'x_coordinate': x_coordinates,
                   'y_coordinate': y_coordinates})

centroids,_ = kmeans(df, 3)
df['cluster_labels'], _ = vq(df, centroids)

sns.scatterplot(x='x_coordinate', y='y_coordinate',
                hue='cluster_labels', data = df)
plt.show()

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
#Example
# Import linkage and fcluster functions
from scipy.cluster.hierarchy import linkage, fcluster

# Use the linkage() function to compute distance
Z = linkage(df, 'ward')

# Generate cluster labels
df['cluster_labels'] = fcluster(Z, 2, criterion='maxclust')

# Plot the points with seaborn
sns.scatterplot(x="x", y="y", hue="cluster_labels", data=df)
plt.show()

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
#Example
# Import kmeans and vq functions
from scipy.cluster.vq import kmeans, vq

# Compute cluster centers
centroids,_ = kmeans(df, 2)

# Assign cluster labels
df['cluster_labels'], _ = vq(df, centroids)

# Plot the points with seaborn
sns.scatterplot(x="x", y="y", hue="cluster_labels", data=df)
plt.show()

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Data preparation for cluster analysis

# %% [markdown]
# Why do we need to prepare data for clustering?
# - Variables have incomparable units (product dimensions in cm, price in $)
# - Variables with same units have vastly dierent scales and variances (expenditures on cereals, travel)
# - Data in raw form may lead to bias in clustering
# - Clusters may be heavily dependent on one variable
# - Solution: normalization of individual variables

# %% [markdown]
# Normalization of data
# - Normalization: process of rescaling data to a standard deviation of 1
# - x_new = x / std_dev(x)

# %%
from scipy.cluster.vq import whiten
data = [5, 1, 3, 3, 2, 3, 3, 8, 1, 2, 2, 3, 5]

scaled_data = whiten(data)
print(scaled_data)
# [2.73, 0.55, 1.64, 1.64, 1.09, 1.64, 1.64, 4.36, 0.55, 1.09, 1.09, 1.64, 2.73]

# %% [markdown]
# Illustration: normalization of data

# %%
# Import plotting library
from matplotlib import pyplot as plt

# Initialize original, scaled data
plt.plot(data,
         label="original")
plt.plot(scaled_data,
         label="scaled")

# Show legend and display plot
plt.legend()
plt.show()

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
#Example
# Import the whiten function
from scipy.cluster.vq import whiten

goals_for = [4,3,2,3,1,1,2,0,1,4]

# Use the whiten() function to standardize the data
scaled_data = whiten(goals_for)
print(scaled_data)

# %%
#Example
# Plot original data
plt.plot(goals_for, label='original')

# Plot scaled data
plt.plot(scaled_data, label='scaled')

# Show the legend in the plot
plt.legend()

# Display the plot
plt.show()

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
#Example
from scipy.cluster.vq import whiten
from matplotlib import pyplot as plt

# Prepare data
rate_cuts = [0.0025, 0.001, -0.0005, -0.001, -0.0005, 0.0025, -0.001, -0.0015, -0.001, 0.0005]

# Use the whiten() function to standardize the data
scaled_data = whiten(rate_cuts)

# Plot original data
plt.plot(rate_cuts, label='original')

# Plot scaled data
plt.plot(scaled_data, label='scaled')

plt.legend()
plt.show()

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
#Example
# Scale wage and value
fifa['scaled_wage'] = whiten(fifa['eur_wage'])
fifa['scaled_value'] = whiten(fifa['eur_value'])

# Plot the two columns in a scatter plot
fifa.plot(x='scaled_wage', y='scaled_value', kind = 'scatter')
plt.show()

# Check mean and standard deviation of scaled values
print(fifa[['scaled_wage', 'scaled_value']].describe())

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Hierarchical Clustering

# %% [markdown]
# ### Basics of hierarchical clustering

# %% [markdown]
# Creating a distance matrix using linkage

# %%
scipy.cluster.hierarchy.linkage(observations,
                                method='single', #distance from clusters
                                metric='euclidean', #distance metric
                                optimal_ordering=False #how to order data point - we will not use
                               )

# %% [markdown]
# - method : how to calculate the proximity of clusters
# - metric : distance metric
# - optimal_ordering : order data points

# %% [markdown]
# Which method should use?
# - single: based on two closest objects
# - complete: based on two farthest objects
# - average: based on the arithmetic mean of all objects
# - centroid: based on the geometric mean of all objects
# - median: based on the median of all objects
# - ward: based on the sum of squares

# %% [markdown]
# Create cluster labels with fcluster

# %%
scipy.cluster.hierarchy.fcluster(distance_matrix, #output of linkage
                                 num_clusters, #clusters we want to form
                                 criterion
                                )

# %% [markdown]
# - distance_matrix : output of linkage() method
# - num_clusters : number of clusters
# - criterion : how to decide thresholds to form clusters

# %% [markdown]
# Hierarchical clustering with ward method
# ![image.png](attachment:image.png)
#
# Hierarchical clustering with single method
# ![image-2.png](attachment:image-2.png)
#
# Hierarchical clustering with complete method
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# Final thoughts on selecting a method
# - No one right method for all
# - Need to carefully understand the distribution of data

# %%
#Example
# Import the fcluster and linkage functions
from scipy.cluster.hierarchy import fcluster, linkage

# Use the linkage() function
distance_matrix = linkage(comic_con[['x_scaled', 'y_scaled']], method = "ward", metric = 'euclidean')

# Assign cluster labels
comic_con['cluster_labels'] = fcluster(distance_matrix, 2, criterion='maxclust')

# Plot clusters
sns.scatterplot(x='x_scaled', y='y_scaled', 
                hue='cluster_labels', data = comic_con)
plt.show()

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
#Example
# Import the fcluster and linkage functions
from scipy.cluster.hierarchy import fcluster, linkage

# Use the linkage() function
distance_matrix = linkage(comic_con[["x_scaled", "y_scaled"]], method = "single", metric = "euclidean")

# Assign cluster labels
comic_con['cluster_labels'] = fcluster(distance_matrix, 2, criterion = "maxclust")

# Plot clusters
sns.scatterplot(x='x_scaled', y='y_scaled', 
                hue='cluster_labels', data = comic_con)
plt.show()

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
#Example
# Import the fcluster and linkage functions
from scipy.cluster.hierarchy import fcluster, linkage

# Use the linkage() function
distance_matrix = linkage(comic_con[["x_scaled", "y_scaled"]], method = "complete", metric = "euclidean")

# Assign cluster labels
comic_con['cluster_labels'] = fcluster(distance_matrix, 2, criterion = "maxclust")

# Plot clusters
sns.scatterplot(x='x_scaled', y='y_scaled', 
                hue='cluster_labels', data = comic_con)
plt.show()

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Visualize clusters

# %% [markdown]
# Why visualize clusters?
# - Try to make sense of the clusters formed
# - An additional step in validation of clusters
# - Spot trends in data

# %% [markdown]
# An introduction to seaborn
# - seaborn: a Python data visualization library based on matplotlib
# - Has better, easily modifiable aesthetics than matplotlib!
# - Contains functions that make data visualization tasks easy in the context of data analytics
# - Use case for clustering: hue parameter for plots

# %% [markdown]
# Visualize clusters with matplotlib

# %%
import pandas as pd
from matplotlib import pyplot as plt

df = pd.DataFrame({'x': [2, 3, 5, 6, 2],
                   'y': [1, 1, 5, 5, 2],
                   'labels': ['A','A','B','B','A']})

colors = {'A':'red','B':'blue'}

df.plot.scatter(x='x',
                y='y',
                c=df['labels'].apply(lambda x: colors[x]))

plt.show()

# %% [markdown]
# Visualize clusters with seaborn

# %%
from matplotlib import pyplot as plt
import seaborn as sns

df = pd.DataFrame({'x': [2, 3, 5, 6, 2],
                   'y': [1, 1, 5, 5, 2],
                   'labels': ['A','A','B','B','A']})

sns.scatterplot(x='x',
                y='y',
                hue='labels',
                data=df)

plt.show()

# %% [markdown]
# Comparison of both methods of visualization

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
#Example
# Import the pyplot class
from matplotlib import pyplot as plt

# Define a colors dictionary for clusters
colors = {1:'red', 2:'blue'}

# Plot a scatter plot
comic_con.plot.scatter(x="x_scaled", 
                	   y="y_scaled",
                	   c=comic_con['cluster_labels'].apply(lambda x: colors[x]))
plt.show()

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
#Example
# Import the seaborn module
import seaborn as sns

# Plot a scatter plot using seaborn
sns.scatterplot(x="x_scaled", 
                y="y_scaled", 
                hue="cluster_labels", 
                data = comic_con)
plt.show()

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### How many clusters?

# %% [markdown]
# Introduction to dendrograms
# - Strategy till now - decide clusters on visual inspection
# - Dendrograms help in showing progressions as clusters are merged
# - A dendrogram is a branching diagram that demonstrates how each cluster is composed by branching out into its child nodes

# %% [markdown]
# Create a dendrogram in SciPy

# %%
from scipy.cluster.hierarchy import dendrogram

Z = linkage(df[['x_whiten','y_whiten']],
            method='ward',
            metric='euclidean')
dn = dendrogram(Z)
plt.show()

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)
#
# ![image-3.png](attachment:image-3.png)

# %%
#Example
# Import the dendrogram function
from scipy.cluster.hierarchy import dendrogram

# Create a dendrogram
dn = dendrogram(linkage(comic_con[["x_scaled", "y_scaled"]], method = "ward", metric = "euclidean"))

# Display the dendogram
plt.show()

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Limitations of hierarchical clustering

# %% [markdown]
# Measuring speed in hierarchical clustering
# - timeit module
# - Measure the speed of .linkage() method
# - Use randomly generated points
# - Run various iterations to extrapolate

# %% [markdown]
# Use of timeit module

# %%
from scipy.cluster.hierarchy import linkage
import pandas as pd
import random, timeit

points = 100
df = pd.DataFrame({'x': random.sample(range(0, points), points),
                   'y': random.sample(range(0, points), points)})

# %timeit linkage(df[['x','y']], method = 'ward', metric = 'euclidean')
# 1.02 ms ± 133 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)

# %% [markdown]
# Comparison of runtime of linkage method
# - Increasing runtime with data points
# - Quadratic increase of runtime
# - Not feasible for large datasets

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
#Example
# Fit the data into a hierarchical clustering algorithm
distance_matrix = linkage(fifa[['scaled_sliding_tackle', 'scaled_aggression']], 'ward')

# Assign cluster labels to each row of data
fifa['cluster_labels'] = fcluster(distance_matrix, 3, criterion='maxclust')

# Display cluster centers of each cluster
print(fifa[['scaled_sliding_tackle', 'scaled_aggression', 'cluster_labels']].groupby('cluster_labels').mean())

# Create a scatter plot through seaborn
sns.scatterplot(x="scaled_sliding_tackle", y="scaled_aggression", hue="cluster_labels", data=fifa)
plt.show()

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## K-Means clustering

# %% [markdown]
# ### Basics of k-means clustering

# %% [markdown]
# Why k-means clustering?
# - A critical drawback of hierarchical clustering: runtime
# - K means runs signicantly faster on large datasets

# %% [markdown]
# Step 1: Generate cluster centers

# %%
kmeans(obs, k_or_guess, iter, thresh, check_finite)

# %% [markdown]
# - obs : standardized observations
# - k_or_guess : number of clusters
# - iter : number of iterations (default: 20)
# - thres : threshold (default: 1e-05)
# - check_finite : whether to check if observations contain only finite numbers (default: True)
#
# Returns two objects: cluster centers (code book), distortion

# %% [markdown]
# How is distortion calculated?

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Step 2: Generate cluster labels

# %%
vq(obs, code_book, check_finite=True)

# %% [markdown]
# obs : standardized observations
# - code_book : cluster centers (first output of the k-means method)
# - check_finite : whether to check if observations contain only finite numbers (default: True)
#
# Returns two objects: a list of cluster labels, a list of distortions

# %% [markdown]
# A note on distortions
# - kmeans returns a single value of distortions
# - vq returns a list of distortions

# %% [markdown]
# Running k-means

# %%
# Import kmeans and vq functions
from scipy.cluster.vq import kmeans, vq
# Generate cluster centers and labels
cluster_centers, _ = kmeans(df[['scaled_x','scaled_y']], 3)

df['cluster_labels'], _= vq(df[['scaled_x','scaled_y']], 
                            cluster_centers)
# Plot clusters
sns.scatterplot(x='scaled_x', 
                y='scaled_y', 
                hue='cluster_labels', 
                data=df)
plt.show()

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
#Example
# Import the kmeans and vq functions
from scipy.cluster.vq import kmeans, vq

# Generate cluster centers
cluster_centers, distortion = kmeans(comic_con[["x_scaled", "y_scaled"]],2)

# Assign cluster labels
comic_con['cluster_labels'], distortion_list = vq(comic_con[["x_scaled", "y_scaled"]], cluster_centers)

# Plot clusters
sns.scatterplot(x='x_scaled', y='y_scaled', 
                hue='cluster_labels', data = comic_con)
plt.show()

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### How many clusters?

# %% [markdown]
# How to find the right k?
# - No absolute method to find right number of clusters (k) in k-means clustering
# - Elbow method

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Distortions revisited
# - Distortion: sum of squared distances of points from cluster centers
# - Decreases with an increasing number of clusters
# - Becomes zero when the number of clusters equals the number of points
# - Elbow plot: line plot between cluster centers and distortion

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Elbow method
# - Elbow plot: plot of the number of clusters and distortion
# - Elbow plot helps indicate number of clusters present in data

# %% [markdown]
# Elbow method in Python

# %%
# Declaring variables for use
distortions = []
num_clusters = range(2, 7)

# Populating distortions for various clusters
for i in num_clusters:
    centroids, distortion = kmeans(df[['scaled_x','scaled_y']], i)
    distortions.append(distortion)

# Plotting elbow plot data
elbow_plot_data = pd.DataFrame({'num_clusters': num_clusters,
                                'distortions': distortions})

sns.lineplot(x='num_clusters', y='distortions',
             data = elbow_plot_data)

plt.show()

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Final thoughts on using the elbow method
# - Only gives an indication of optimal_k_ (numbers of clusters)
# - Does not always pinpoint how many_k_ (numbers of clusters)
# - Other methods: average silhouette and gap statistic

# %%
#Example
distortions = []
num_clusters = range(1, 7)

# Create a list of distortions from the kmeans function
for i in num_clusters:
    cluster_centers, distortion = kmeans(comic_con[["x_scaled", "y_scaled"]], i)
    distortions.append(distortion)

# Create a DataFrame with two lists - num_clusters, distortions
elbow_plot = pd.DataFrame({'num_clusters': num_clusters, 'distortions': distortions})

# Creat a line plot of num_clusters and distortions
sns.lineplot(x="num_clusters", y="distortions", data = elbow_plot)
plt.xticks(num_clusters)
plt.show()

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
#Example
distortions = []
num_clusters = range(2, 7)

# Create a list of distortions from the kmeans function
for i in num_clusters:
    cluster_centers, distortion = kmeans(uniform_data[["x_scaled", "y_scaled"]], i )
    distortions.append(distortion)

# Create a DataFrame with two lists - number of clusters and distortions
elbow_plot = pd.DataFrame({'num_clusters': num_clusters, 'distortions': distortions})

# Creat a line plot of num_clusters and distortions
sns.lineplot(x="num_clusters", y="distortions", data=elbow_plot)
plt.xticks(num_clusters)
plt.show()

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Limitation of k-means clustering

# %% [markdown]
# Limitations of k-means clustering
# - How to nd the right _K_ (number of clusters)?
# - Impact of seeds
# - Biased towards equal sized clusters

# %% [markdown]
# Impact of seeds
# - Initialize a random seed

# %%
from numpy import random
random.seed(12)

# %% [markdown]
# - Seed: np.array(1000, 2000)
# - Cluster sizes: 29, 29, 43, 47, 52
#
#
# - Seed: np.array(1,2,3)
# - Cluster sizes: 26, 31, 40, 50, 53

# %% [markdown]
# Impact of seeds: plots

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Uniform clusters in k means

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Uniform clusters in k-means: a comparison

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Final thoughts
# - Each technique has its pros and cons
# - Consider your data size and paerns before deciding on algorithm
# - Clustering is exploratory phase of analysis

# %%
# Import random class
from numpy import random

# Initialize seed
random.seed([1,2,1000])

# Run kmeans clustering
cluster_centers, distortion = kmeans(comic_con[['x_scaled', 'y_scaled']], 2)
comic_con['cluster_labels'], distortion_list = vq(comic_con[['x_scaled', 'y_scaled']], cluster_centers)

# Plot the scatterplot
sns.scatterplot(x='x_scaled', y='y_scaled', 
                hue='cluster_labels', data = comic_con)
plt.show()

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
#Example
# Import the kmeans and vq functions
from scipy.cluster.vq import kmeans, vq

# Generate cluster centers
cluster_centers, distortion = kmeans(mouse[["x_scaled", "y_scaled"]], 3)

# Assign cluster labels
mouse['cluster_labels'], distortion_list = vq(mouse[["x_scaled", "y_scaled"]], cluster_centers)

# Plot clusters
sns.scatterplot(x='x_scaled', y='y_scaled', 
                hue='cluster_labels', data = mouse)
plt.show()

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
#Example
# Set up a random seed in numpy
random.seed([1000,2000])

# Fit the data into a k-means algorithm
cluster_centers,_ = kmeans(fifa[['scaled_def', 'scaled_phy']], 3)

# Assign cluster labels
fifa['cluster_labels'], _ = vq(fifa[['scaled_def', 'scaled_phy']], cluster_centers)

# Display cluster centers 
print(fifa[['scaled_def', 'scaled_phy', 'cluster_labels']].groupby('cluster_labels').mean())

# Create a scatter plot through seaborn
sns.scatterplot(x="scaled_def", y="scaled_phy", hue="cluster_labels", data=fifa)
plt.show()

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Clustering in Real World

# %% [markdown]
# ### Dominant colors in image

# %% [markdown]
# Dominant colors in images
# - All images consist of pixels
# - Each pixel has three values: Red, Green and Blue
# - Pixel color: combination of these RGB values
# - Perform k-means on standardized RGB values to nd cluster centers
# - Uses: Identifying features in satellite images

# %% [markdown]
# ![image.png](attachment:image.png)
# https://www.datagenetics.com/blog/march12012/index.html

# %% [markdown]
# Feature identification in satellite images
# ![image.png](attachment:image.png)
# https://www.semanticscholar.org/paper/K-Means-Based-SVD-for-Multiband-Satellite-Image-Al-Ghrairi-Altaei/a4abfd2be3f73577f526db70254624346c3ca3aa?p2df

# %% [markdown]
# Tools to find dominant colors
# - Convert image to pixels: matplotlib.image.imread
# - Display colors of cluster centers: matplotlib.pyplot.imshow

# %% [markdown]
# K-means on this image:
# ![image.png](attachment:image.png)
# blue green water and light blue sky

# %% [markdown]
# Convert image to RGB matrix

# %%
import matplotlib.image as img
image = img.imread('sea.jpg')
image.shape
# (475, 764, 3)

r = []
g = []
b = []

#abre para cada linha, composta por 3 fatores de r, g, b
for row in image:
    for pixel in row:
    # A pixel contains RGB values
    temp_r, temp_g, temp_b = pixel
    r.append(temp_r)
    g.append(temp_g)
    b.append(temp_b)

# %% [markdown]
# DataFrame with RGB values

# %%
#transforma em dataframe
pixels = pd.DataFrame({'red': r,
                       'blue': b,
                       'green': g})
pixels.head()

#red blue green
# 252 255 252
# 75 103 81
# ... ... ...

# %% [markdown]
# Create an elbow plot

# %%
distortions = []
num_clusters = range(1, 11)

# Create a list of distortions from the kmeans method
for i in num_clusters:
    cluster_centers, _= kmeans(pixels[['scaled_red','scaled_blue',
                                       'scaled_green']], i)

    distortions.append(distortion)

# Create a DataFrame with two lists - number of clusters and distortions
elbow_plot = pd.DataFrame({'num_clusters': num_clusters,
                           'distortions': distortions})

# Creat a line plot of num_clusters and distortions
sns.lineplot(x='num_clusters', y='distortions', data = elbow_plot)
plt.xticks(num_clusters)
plt.show()

#two prominant colors

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Find dominant colors

# %%
cluster_centers, _= kmeans(pixels[['scaled_red','scaled_blue',
                                   'scaled_green']], 2)

colors = []

# Find Standard Deviations
r_std, g_std, b_std = pixels[['red', 'blue','green']].std()

# Scale actual RGB values in range of 0-1
for cluster_center in cluster_centers:
    scaled_r, scaled_g, scaled_b = cluster_center
    colors.append((
        scaled_r * r_std/255,
        scaled_g * g_std/255,
        scaled_b * b_std/255
    ))

# %% [markdown]
# Display dominant colors

# %%
#Dimensions: 2 x 3 (N X 3 matrix)
print(colors)

# [(0.08192923122023911, 0.34205845943857993, 0.2824002984155429),
#  (0.893281510956742, 0.899818770315129, 0.8979114272960784)]

#Dimensions: 1 x 2 x 3 (1 X N x 3 matrix)
plt.imshow([colors])
plt.show()

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Example
# ![image.png](attachment:image.png)

# %%
#Example
# Import image class of matplotlib
import matplotlib.image as img

# Read batman image and print dimensions
batman_image = img.imread('batman.jpg')
print(batman_image.shape)

# Store RGB values of all pixels in lists r, g and b
for row in batman_image:
    for temp_r, temp_g, temp_b in row:
        r.append(temp_r)
        g.append(temp_g)
        b.append(temp_b)

# %% [markdown]
# I printted the values of batman_image and then the shape
# ![image.png](attachment:image.png)

# %%
#Example
distortions = []
num_clusters = range(1, 7)

# Create a list of distortions from the kmeans function
for i in num_clusters:
    cluster_centers, distortion = kmeans(batman_df[["scaled_red", "scaled_blue", "scaled_green"]], i)
    distortions.append(distortion)

# Create a DataFrame with two lists, num_clusters and distortions
elbow_plot = pd.DataFrame({"num_clusters": num_clusters, "distortions": distortions})

# Create a line plot of num_clusters and distortions
sns.lineplot(x="num_clusters", y="distortions", data = elbow_plot)
plt.xticks(num_clusters)
plt.show()

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
#Example
# Get standard deviations of each color
r_std, g_std, b_std = batman_df[['red', 'green', 'blue']].std()

for cluster_center in cluster_centers:
    scaled_r, scaled_g, scaled_b = cluster_center
    # Convert each standardized value to scaled value
    colors.append((
        scaled_r * r_std / 255,
        scaled_g * g_std / 255,
        scaled_b * b_std / 255
    ))

# Display colors of cluster centers
plt.imshow([colors])
plt.show()

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Document clustering

# %% [markdown]
# Document clustering: concepts (it uses NLP)
# 1. Clean data before processing (things that do not add value. ponctuation, emoticons, words such as is/are etc
# 2. Determine the importance of the terms in a document (in TF-IDF matrix)
# 3. Cluster the TF-IDF matrix
# 4. Find top terms, documents in each cluster

# %% [markdown]
# Clean and tokenize data
# - Convert text into smaller parts called tokens, clean data for processing

# %%
from nltk.tokenize import word_tokenize
import re

def remove_noise(text, stop_words = []):
    tokens = word_tokenize(text)
    cleaned_tokens = []
    for token in tokens:
        token = re.sub('[^A-Za-z0-9]+', '', token)
        if len(token) > 1 and token.lower() not in stop_words:
            # Get lowercase
            cleaned_tokens.append(token.lower())
    return cleaned_tokens

remove_noise("It is lovely weather we are having. I hope the weather continues.")
# ['lovely','weather','hope','weather','continues']

# %% [markdown]
# Document term matrix and sparse matrices
# - Document term matrix formed
# - Most elements in matrix are zeros
# ![image.png](attachment:image.png)
# http://brandonrose.org/clustering
#
# - Sparse matrix is created (store it more efficiently)
# ![image-2.png](attachment:image-2.png)
# https://www.geeksforgeeks.org/sparse-matrix-representation/

# %% [markdown]
# TF-IDF (Term Frequency - Inverse Document Frequency)
# - A weighted measure: evaluate how important a word is to a document in a collection

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

tfidf_vectorizer = TfidfVectorizer(max_df=0.8, max_features=50,
                                   min_df=0.2, tokenizer=remove_noise)

tfidf_matrix = tfidf_vectorizer.fit_transform(data)

# %% [markdown]
# Clustering with sparse matrix
# - kmeans() in SciPy does not support sparse matrices
# - Use .todense() to convert to a matrix

# %%
cluster_centers, distortion = kmeans(tfidf_matrix.todense(), num_clusters)

# %% [markdown]
# Top terms per cluster
# - Cluster centers: lists with a size equal to the number of terms
# - Each value in the cluster center is its importance
# - Create a dictionary and print top terms

# %%
terms = tfidf_vectorizer.get_feature_names()
for i in range(num_clusters):
    center_terms = dict(zip(terms, list(cluster_centers[i])))
    sorted_terms = sorted(center_terms, key=center_terms.get, reverse=True)
    print(sorted_terms[:3])

# ['room','hotel','staff']
# ['bad','location','breakfast']

# %% [markdown]
# More considerations
# - Work with hyperlinks, emoticons etc.
# - Normalize words (run, ran, running -> run)
# - .todense() may not work with large datasets

# %%
#Example - cluster movies based on synopses <3
# Import TfidfVectorizer class from sklearn
from sklearn.feature_extraction.text import TfidfVectorizer

# Initialize TfidfVectorizer
tfidf_vectorizer = TfidfVectorizer(max_df = 0.75, max_features = 50, min_df = 0.1, tokenizer = remove_noise)

# Use the .fit_transform() method on the list plots
tfidf_matrix = tfidf_vectorizer.fit_transform(plots)

# %%
#Example
num_clusters = 2

# Generate cluster centers through the kmeans function
cluster_centers, distortion = kmeans(tfidf_matrix.todense(), num_clusters)

# Generate terms from the tfidf_vectorizer object
terms = tfidf_vectorizer.get_feature_names()

for i in range(num_clusters):
    # Sort the terms and print top 3 terms
    center_terms = dict(zip(terms, list(cluster_centers[i])))
    sorted_terms = sorted(center_terms, key=center_terms.get, reverse=True)
    print(sorted_terms[:3])

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Clustering with multiple features

# %% [markdown]
# Basic checks

# %%
# Cluster centers
print(fifa.groupby('cluster_labels')[['scaled_heading_accuracy', 
                                      'scaled_volleys','scaled_finishing']].mean())
#USE THE CLUSTER LABELS TO GROUPBY THE DATA
# cluster_labels scaled_heading_accuracy scaled_volleys scaled_nishing
#             0    3.21                   2.83           2.76
#             1    0.71                   0.64           0.58

# %%
# Cluster sizes
print(fifa.groupby('cluster_labels')['ID'].count())

# cluster_labels count
# 0                886
# 1                114

# %% [markdown]
# Visualizations
# - Visualize cluster centers
# - Visualize other variables for each cluster

# %%
# Plot cluster centers
fifa.groupby('cluster_labels') \
        [scaled_features].mean() \
        .plot(kind='bar')

plt.show()

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Top items in clusters

# %%
# Get the name column of top 5 players in each cluster
for cluster in fifa['cluster_labels'].unique():
    print(cluster, fifa[fifa['cluster_labels'] == cluster]['name'].values[:5])

# Cluster Label Top Players
# 0             ['Cristiano Ronaldo' 'L. Messi' 'Neymar' 'L. Suárez' 'R. Lewandowski']
# 1             ['M. Neuer' 'De Gea' 'G. Buon' 'T. Courtois' 'H. Lloris']

# %% [markdown]
# Feature reduction
# - Factor analysis
# - Multidimensional scaling

# %%
#Example
# Print the size of the clusters
print(fifa.groupby("cluster_labels")['ID'].count())

# Print the mean value of wages in each cluster
print(fifa.groupby("cluster_labels")['eur_wage'].mean())

# %%
#Example
# Create centroids with kmeans for 2 clusters
cluster_centers,_ = kmeans(fifa[scaled_features], 2)

# Assign cluster labels and print cluster centers
fifa['cluster_labels'], _ = vq(fifa[scaled_features], cluster_centers)
print(fifa.groupby('cluster_labels')[scaled_features].mean())

# Plot cluster centers to visualize clusters
fifa.groupby('cluster_labels')[scaled_features].mean().plot(legend=True, kind='bar')
plt.show()

# Get the name column of first 5 players in each cluster
for cluster in fifa['cluster_labels'].unique():
    print(cluster, fifa[fifa['cluster_labels'] == cluster]["name"].values[:5])

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Farewell!

# %% [markdown]
# What comes next?
# - Clustering is one of the exploratory steps
# - More courses on DataCamp
# - Practice, practice, practice!
