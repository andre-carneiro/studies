# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#INTRODUCTION-TO-LINEAR-MODELING-IN-PYTHON" data-toc-modified-id="INTRODUCTION-TO-LINEAR-MODELING-IN-PYTHON-1"><span class="toc-item-num">1&nbsp;&nbsp;</span><strong>INTRODUCTION TO LINEAR MODELING IN PYTHON</strong></a></span><ul class="toc-item"><li><span><a href="#Exploring-Linear-Trends" data-toc-modified-id="Exploring-Linear-Trends-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Exploring Linear Trends</a></span><ul class="toc-item"><li><span><a href="#Introduction-to-Modeling-Data" data-toc-modified-id="Introduction-to-Modeling-Data-1.1.1"><span class="toc-item-num">1.1.1&nbsp;&nbsp;</span>Introduction to Modeling Data</a></span></li><li><span><a href="#Visualizing-Linear-Relationships" data-toc-modified-id="Visualizing-Linear-Relationships-1.1.2"><span class="toc-item-num">1.1.2&nbsp;&nbsp;</span>Visualizing Linear Relationships</a></span></li><li><span><a href="#Quantifying-Linear-Relationships" data-toc-modified-id="Quantifying-Linear-Relationships-1.1.3"><span class="toc-item-num">1.1.3&nbsp;&nbsp;</span>Quantifying Linear Relationships</a></span></li></ul></li><li><span><a href="#Building-Linear-Models" data-toc-modified-id="Building-Linear-Models-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Building Linear Models</a></span><ul class="toc-item"><li><span><a href="#What-makes-a-model-linear" data-toc-modified-id="What-makes-a-model-linear-1.2.1"><span class="toc-item-num">1.2.1&nbsp;&nbsp;</span>What makes a model linear</a></span></li><li><span><a href="#Interpreting-Slope-and-Intercept" data-toc-modified-id="Interpreting-Slope-and-Intercept-1.2.2"><span class="toc-item-num">1.2.2&nbsp;&nbsp;</span>Interpreting Slope and Intercept</a></span></li><li><span><a href="#Model-Optimization" data-toc-modified-id="Model-Optimization-1.2.3"><span class="toc-item-num">1.2.3&nbsp;&nbsp;</span>Model Optimization</a></span></li><li><span><a href="#Least-Squares-Optimization" data-toc-modified-id="Least-Squares-Optimization-1.2.4"><span class="toc-item-num">1.2.4&nbsp;&nbsp;</span>Least-Squares Optimization</a></span></li></ul></li><li><span><a href="#Making-Model-Predictions" data-toc-modified-id="Making-Model-Predictions-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>Making Model Predictions</a></span><ul class="toc-item"><li><span><a href="#Modeling-Real-Data" data-toc-modified-id="Modeling-Real-Data-1.3.1"><span class="toc-item-num">1.3.1&nbsp;&nbsp;</span>Modeling Real Data</a></span></li><li><span><a href="#The-Limits-of-Prediction" data-toc-modified-id="The-Limits-of-Prediction-1.3.2"><span class="toc-item-num">1.3.2&nbsp;&nbsp;</span>The Limits of Prediction</a></span></li><li><span><a href="#Goodness-of-Fit" data-toc-modified-id="Goodness-of-Fit-1.3.3"><span class="toc-item-num">1.3.3&nbsp;&nbsp;</span>Goodness-of-Fit</a></span></li><li><span><a href="#Standard-Error" data-toc-modified-id="Standard-Error-1.3.4"><span class="toc-item-num">1.3.4&nbsp;&nbsp;</span>Standard Error</a></span></li></ul></li><li><span><a href="#Estimating-Model-Parameters" data-toc-modified-id="Estimating-Model-Parameters-1.4"><span class="toc-item-num">1.4&nbsp;&nbsp;</span>Estimating Model Parameters</a></span><ul class="toc-item"><li><span><a href="#Inferential-Statistics-Concepts" data-toc-modified-id="Inferential-Statistics-Concepts-1.4.1"><span class="toc-item-num">1.4.1&nbsp;&nbsp;</span>Inferential Statistics Concepts</a></span></li><li><span><a href="#Model-Estimation-and-Likelihood" data-toc-modified-id="Model-Estimation-and-Likelihood-1.4.2"><span class="toc-item-num">1.4.2&nbsp;&nbsp;</span>Model Estimation and Likelihood</a></span></li><li><span><a href="#Model-Uncertainty-and-Sample-Distributions" data-toc-modified-id="Model-Uncertainty-and-Sample-Distributions-1.4.3"><span class="toc-item-num">1.4.3&nbsp;&nbsp;</span>Model Uncertainty and Sample Distributions</a></span></li><li><span><a href="#Model-Errors-and-Randomness" data-toc-modified-id="Model-Errors-and-Randomness-1.4.4"><span class="toc-item-num">1.4.4&nbsp;&nbsp;</span>Model Errors and Randomness</a></span></li><li><span><a href="#Model-Conclusion" data-toc-modified-id="Model-Conclusion-1.4.5"><span class="toc-item-num">1.4.5&nbsp;&nbsp;</span>Model Conclusion</a></span></li></ul></li></ul></li><li><span><a href="#Generalized-Linear-Models-in-Python" data-toc-modified-id="Generalized-Linear-Models-in-Python-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Generalized Linear Models in Python</a></span><ul class="toc-item"><li><span><a href="#Introduction-to-GLMs" data-toc-modified-id="Introduction-to-GLMs-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Introduction to GLMs</a></span><ul class="toc-item"><li><span><a href="#Going-beyond-linear-regression" data-toc-modified-id="Going-beyond-linear-regression-2.1.1"><span class="toc-item-num">2.1.1&nbsp;&nbsp;</span>Going beyond linear regression</a></span></li><li><span><a href="#How-to-build-a-GLM?" data-toc-modified-id="How-to-build-a-GLM?-2.1.2"><span class="toc-item-num">2.1.2&nbsp;&nbsp;</span>How to build a GLM?</a></span></li><li><span><a href="#How-to-fit-a-GLM-in-Python?" data-toc-modified-id="How-to-fit-a-GLM-in-Python?-2.1.3"><span class="toc-item-num">2.1.3&nbsp;&nbsp;</span>How to fit a GLM in Python?</a></span></li></ul></li><li><span><a href="#Modeling-Binary-Data" data-toc-modified-id="Modeling-Binary-Data-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Modeling Binary Data</a></span><ul class="toc-item"><li><span><a href="#Binaty-data-and-logistic-regression" data-toc-modified-id="Binaty-data-and-logistic-regression-2.2.1"><span class="toc-item-num">2.2.1&nbsp;&nbsp;</span>Binaty data and logistic regression</a></span></li><li><span><a href="#Interpreting-coefficients" data-toc-modified-id="Interpreting-coefficients-2.2.2"><span class="toc-item-num">2.2.2&nbsp;&nbsp;</span>Interpreting coefficients</a></span></li><li><span><a href="#Interpreting-model-inference" data-toc-modified-id="Interpreting-model-inference-2.2.3"><span class="toc-item-num">2.2.3&nbsp;&nbsp;</span>Interpreting model inference</a></span></li><li><span><a href="#Computing-and-describing-predictions" data-toc-modified-id="Computing-and-describing-predictions-2.2.4"><span class="toc-item-num">2.2.4&nbsp;&nbsp;</span>Computing and describing predictions</a></span></li></ul></li><li><span><a href="#Modeling-Count-Data" data-toc-modified-id="Modeling-Count-Data-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Modeling Count Data</a></span><ul class="toc-item"><li><span><a href="#Count-data-and-Poisson-distribution" data-toc-modified-id="Count-data-and-Poisson-distribution-2.3.1"><span class="toc-item-num">2.3.1&nbsp;&nbsp;</span>Count data and Poisson distribution</a></span></li><li><span><a href="#Interpreting-model-fit" data-toc-modified-id="Interpreting-model-fit-2.3.2"><span class="toc-item-num">2.3.2&nbsp;&nbsp;</span>Interpreting model fit</a></span></li><li><span><a href="#The-Problem-of-Overdispersion" data-toc-modified-id="The-Problem-of-Overdispersion-2.3.3"><span class="toc-item-num">2.3.3&nbsp;&nbsp;</span>The Problem of Overdispersion</a></span></li><li><span><a href="#Plotting-a-regression-model" data-toc-modified-id="Plotting-a-regression-model-2.3.4"><span class="toc-item-num">2.3.4&nbsp;&nbsp;</span>Plotting a regression model</a></span></li></ul></li></ul></li></ul></div>

# %% [markdown]
# # **INTRODUCTION TO LINEAR MODELING IN PYTHON**
# Jason Vestuto

# %% [markdown]
# ## Exploring Linear Trends

# %% [markdown]
# ### Introduction to Modeling Data

# %% [markdown]
# Introduction to Chapter 1
# - Chapter Roadmap:
#     - Motivating Examples
#     - Data Visualization
#     - Descriptive Statistics

# %% [markdown]
# Example Trip Data
# ![image.png](attachment:image.png)

# %% [markdown]
# Models as Descriptions

# %%
# Range of y data, in miles
y_
range = np.max(y) - np.min(y) = 300 - 0 = 300
# Range of x data, in hours
x
_
range = np.max(x) - np.min(x) = 6 - 0 = 6
# Estimating the speed
mph = y_
range / x
_
range = 300 / 6 = 50

# %% [markdown]
# Visualizing a Model
# ![image.png](attachment:image.png)

# %% [markdown]
# Model Predictions

# %%
# Model as python expression
miles = 50*hours
# Model predicts distance is 300 miles at 6 hours
time = 6
distance = 50 * time = 50 * 6 = 300
def model(time):
return 50*time
predicted
_
distance = model(time=10)

# %% [markdown]
# Interpolation
# ![image.png](attachment:image.png)

# %% [markdown]
# Extrapolation
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Visualizing Linear Relationships

# %% [markdown]
# Quick Plots

# %%
import matplotlib.pyplot as plt
plt.plot(x, y,
'r-o')
plt.show()

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Object Interface

# %%
# Import the pyplot module
import matplotlib.pyplot as plt
# Create figure and axis objects
fig, axis = plt.subplots()
# Prepare initial style options
options = dict(marker='o'
, color='blue')

# %%
# Call the plot method on the axis object
line = axis.plot(x, y, **options)
# Modify the axis object with set methods
_
= axis.set
_ylabel('Times')
_
= axis.set
_
xlabel('Distances')
# Display figure
plt.show()

# %% [markdown]
# Visualizing Linear Data
# - two points:
#     - (x1,y1) = (0,0)
#     - (x2,y2) = (2,3)
# - change in x and y:
#     - dy = (y2 - y1) = 3 - 0
#     - dx = (x2 - x1) = 2 - 0
# - slope = rise-over-run
#     - slope = dy/dx = 3/2
# - intercept:
#     - when x=0 : y1 = 0
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Quantifying Linear Relationships

# %% [markdown]
# Pre-Visualization
# ![image.png](attachment:image.png)

# %% [markdown]
# Review of Single Variable Statistics

# %%
# Mean
mean = sum(x)/len(x)
# Deviation, sometimes called "centering"
dx = x - np.mean(x)
# Variance
variance = np.mean(dx*dx)
# Standard Deviation
stdev = np.sqrt(variance)

# %% [markdown]
# Covariance

# %%
# Deviations of two variables
dx = x - np.mean(x)
dy = y - np.mean(y)
# Co-vary means to vary together
deviation
_products = dx*dy
# Covariance as the mean
covariance = np.mean(dx*dy)

# %% [markdown]
# Correlation

# %%
# Divide deviations by standard deviation
zx = dx/np.std(x)
zy = dy/np.std(y)
# Mean of the normalize deviations
correlation = np.mean(zx*zy)

# %% [markdown]
# Normalization: Before
# ![image.png](attachment:image.png)

# %% [markdown]
# Normalization: After
# ![image.png](attachment:image.png)

# %% [markdown]
# Magnitude versus Direction
# - Correlation values: -1 to +1
# ![image.png](attachment:image.png)
# - Two Parts: Magnitude (1 to 0) versus Sign (+ or -)

# %% [markdown]
# ## Building Linear Models

# %% [markdown]
# ### What makes a model linear

# %% [markdown]
# Taylor Series
# - Things to know:
#     - 1. approximate any curve
#     - 2. polynomial form: y = a0 + a1*x + a2*x**2 + a3*x**3 + .... + an*x**n
#     - 3. often, first order is enough: y = a0 + a1*x

# %% [markdown]
# Series Terms: a0=1
# ![image.png](attachment:image.png)

# %% [markdown]
# Series Terms: a1=1
# ![image.png](attachment:image.png)

# %% [markdown]
# Series Terms: a2=1
# ![image.png](attachment:image.png)

# %% [markdown]
# Combining all Terms
# ![image.png](attachment:image.png)

# %% [markdown]
# Real Data
# ![image.png](attachment:image.png)

# %% [markdown]
# Zeroth Order
# ![image.png](attachment:image.png)

# %% [markdown]
# First Order
# ![image.png](attachment:image.png)

# %% [markdown]
# Higher Order
# ![image.png](attachment:image.png)

# %% [markdown]
# Over-fitting
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Interpreting Slope and Intercept

# %% [markdown]
# Reminder: Terminology
# - Review:
#     - y = a0 %20 a1*x
#     - x = independent variable, e.g. time
#     - y = dependent variable, e.g. distance traveled
#     - xp = 10; yp = a0 %20 a1*xp , "model prediction"

# %% [markdown]
# Intercept
# ![image.png](attachment:image.png)

# %%
x0 = 0
print(y(x0))
100

# %% [markdown]
# Slope
# ![image.png](attachment:image.png)

# %%
slope = (225 - 100) / (5 - 0)
print(slope)
25

# %% [markdown]
# Average Slope
# ![image.png](attachment:image.png)

# %%
slope = (350 - 100) / (10 - 0)
print(slope)
25

# %% [markdown]
# Rescaling versus Dependency
# ![image.png](attachment:image.png)

# %%
slope = (212-32)/(100-0) # 180/100 = 9/5
intercept = 32

# %% [markdown]
# ### Model Optimization

# %% [markdown]
# Residuals
# ![image.png](attachment:image.png)

# %%
residuals = y_
model - y_
data
len(residuals) == len(y_
data)
True

# %% [markdown]
# Residuals Summed
# ![image.png](attachment:image.png)

# %%
residuals = y_
model - y_
data
print(np.sum(residuals))
0.0

# %% [markdown]
# Residuals Squared
# ![image.png](attachment:image.png)

# %%
residuals
_
squared = np.square(y_
model - y
                    print(np.sum(residuals
_
squared))
                    65.1

# %% [markdown]
# RSS
# ![image.png](attachment:image.png)

# %%
resid
_
squared = np.square(y_
model - y_
data)
RSS = np.sum(resid
_
squared)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
5.9
RSS = np.sum(np.square(y_
model - y_
data))
print(RSS)

# %% [markdown]
# Variation of RSS
# ![image.png](attachment:image.png)
# Minimum value of RSS gives minimum
# residuals
# Minimum residuals give the best model

# %% [markdown]
# ### Least-Squares Optimization

# %% [markdown]
# Minima of RSS
# ![image.png](attachment:image.png)
# Seing RSS slope = zero, and some calculus, yields:
# a = covariance(x, y)/variance(x)
# a = mean(y) − a × mean(x)

# %% [markdown]
# Optimized by Numpy
# Numpy expressions of optimal slope and intercept

# %%
x
_
mean = np.mean(x)
y_
mean = np.mean(y)
x
_
dev = x - x
_
mean
y_
dev = y - y_
mean
a1 = np.sum( x
_
dev * y_
dev ) / np.sum( x
_
dev**2 )
a0 = y_
mean - (a1*x
_
mean)

# %% [markdown]
# Optimized by Scipy

# %%
from scipy import optimize
x
_
data, y_
data = load
_
data()
def model
_
func(x, a0, a1):
return a0 + (a1*x)
param
_
opt, param
_
cov = optimize.curve
_
fit(model
_
func, x
_
data, y_
data)
a0 = param
_
opt[0] # a0 is the intercept in y = a0 + a1*x
a1 = param
_
opt[1] # a1 is the slope in y = a0 + a1*x

# %% [markdown]
# Optimized by Statsmodels

# %%
from statsmodels.formula.api import ols
x
_
data, y_
data = load
_
data()
df = pd.DataFrame(dict(x
_
name=x
_
data, y_
name=y_
data))
model
_
fit = ols(formula="y_
name ~ x
_
name"
, data=df).fit()
y_
model = model
_
fit.predict(df)
x
_
model = x
_
data
a0 = model
_
fit.params['Intercept']
a1 = model
_
fit.params['x
_
name']

# %% [markdown]
# ## Making Model Predictions

# %% [markdown]
# ### Modeling Real Data

# %% [markdown]
# Scikit-Learn

# %%
from sklearn.linear
_
model import LinearRegression
# Initialize a general model
model = LinearRegression(fit
_
intercept=True)
# Load and shape the data
x
_
raw, y_
raw = load
_
data()
x
_
data = x
_
raw.reshape(len(y_
raw),1)
y_
data = y_
raw.reshape(len(y_
raw),1)
# Fit the model to the data
model
_
fit = model.fit(x
_
data, y_
data)

# %% [markdown]
# Predictions and Parameters

# %%
# Extract the linear model parameters
intercept = model.intercept
_[0]
slope = model.coef
_[0,0]
# Use the model to make predictions
future
_
x = 2100
future
_y = model.predict(future
_
x)

# %% [markdown]
# statsmodels

# %%
x, y = load
_
data()
df = pd.DataFrame(dict(times=x
_
data, distances=y_
data))
fig = df.plot('times'
,
'distances')
model
_
fit = ols(formula="distances ~ times"
, data=df).fit()

# %% [markdown]
# Uncertainty

# %%
a0 = model
_
fit.params['Intercept']
a1 = model
_
fit.params['times']
e0 = model
_
fit.bse['Intercept']
e1 = model
_
fit.bse['times']
intercept = a0
slope = a1
uncertainty_
in
_
intercept = e0
uncertainty_
in
_
slope = e1

# %% [markdown]
# ### The Limits of Prediction

# %% [markdown]
# Interpolation
# ![image.png](attachment:image.png)
# ![image.png](attachment:image.png)
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# Domain of Validity
# - zoom in: data looks linear
# - model assumption: a2*x**2 + a3*x**3 + ... = zero.
# - build a linear model: a0 + a1*x
# - zoom out: your model breaks

# %% [markdown]
# Extrapolating Too Far
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Goodness-of-Fit

# %% [markdown]
# 3 Different R's
# - Building Models:
#     - RSS
# - Evaluating Models:
#     - RMSE
#     - R-squared

# %% [markdown]
# RMSE

# %%
residuals = y_
model - y_
data
RSS = np.sum( np.square(residuals) )
mean
_
squared
_
residuals = np.sum( np.square(residuals) ) / len(residuals)
MSE = np.mean( np.square(residuals) )
RMSE = np.sqrt(np.mean( np.square(residuals)))
RMSE = np.std(residuals)

# %% [markdown]
# R-Squared in Code

# %% [markdown]
# Deviations:

# %%
deviations = np.mean(y_
data) - y_
data
VAR = np.sum(np.square(deviations))

# %% [markdown]
# Residuals:

# %%
residuals = y_
model - y_
data
RSS = np.sum(np.square(residuals))

# %% [markdown]
# R-squared:

# %%
r
_
squared = 1 - (RSS / VAR)
r = correlation(y_
data, y_
model)

# %% [markdown]
# R-Squared in Data
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)
# ![image-3.png](attachment:image-3.png)
# ![image-4.png](attachment:image-4.png)

# %% [markdown]
# RMSE vs R-Squared
# - RMSE: how much variation is residual
# - R-squared: what fraction of variation is linear

# %% [markdown]
# ### Standard Error

# %% [markdown]
# Uncertainty in Predictions
# - Model Predictions and RMSE:
#     - predictions compared to data gives residuals
#     - residuals have spread
#     - RMSE, measures residual spread
#     - RMSE, quanties prediction goodness
# - Model Parameters and Standard Error:
#     - Parameter value as center
#     - Parameter standard error as spread
#     - Standard Error, measures parameter uncertainty

# %% [markdown]
# Computing Standard Errors

# %%
df = pd.DataFrame(dict(times=x
_
data, distances=y_
data))
model
_
fit = ols(formula="distances ~ times"
, data=df).fit()
a1 = model
_
fit.params['times']
a0 = model
_
fit.params['Intercept']
slope = a1
intercept = a0

# %%
e0 = model
_
fit.bse['Intercept']
e1 = model
_
fit.bse['times']
standard
_
error
_
of
_
intercept = e0
standard
_
error
_
of
_
slope = e1

# %% [markdown]
# ## Estimating Model Parameters

# %% [markdown]
# ### Inferential Statistics Concepts

# %% [markdown]
# Probability Distribution
# Populations and Statistics
# ![image.png](attachment:image.png)

# %% [markdown]
# Sampling the Population

# %% [markdown]
# Population statistics vs Sample statistics

# %%
print( len(month
_
of
_
temps), month
_
of
_
temps.mean(), month
_
of
_
temps.std() )
print( len(decade
_
of
_
temps), decade
_
of
_
temps.mean(), decade
_
of
_
temps.std() )

# %% [markdown]
# Draw a Random Sample from a Population

# %%
month
_
of
_
temps = np.random.choice(decade
_
of
_
temps, size=31)

# %% [markdown]
# Visualizing Distributions
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# Probability and Inference
# ![image.png](attachment:image.png)

# %% [markdown]
# Visualizing Distributions
# ![image.png](attachment:image.png)

# %% [markdown]
# Resampling

# %%
# Resampling as Iteration
num
_
samples = 20
for ns in range(num
_
samples):
sample = np.random.choice(population, num
_pts)
distribution
_
of
_
means[ns] = sample.mean()
# Sample Distribution Statistics
mean
_
of
_
means = np.mean(distribution
_
of
_
means)
stdev
_
of
_
means = np.std(distribution
_
of
_
means)

# %% [markdown]
# ### Model Estimation and Likelihood

# %% [markdown]
# Estimation
# ![image.png](attachment:image.png)

# %%
# Define gaussian model function
def gaussian
_
model(x, mu, sigma):
coeff
_part = 1/(np.sqrt(2 * np.pi * sigma**2))
exp_part = np.exp( - (x - mu)**2 / (2 * sigma**2) )
return coeff
_part*exp_part
# Compute sample statistics
mean = np.mean(sample)
stdev = np.std(sample)
# Model the population using sample statistics
population
_
model = gaussian(sample, mu=mean, sigma=stdev)

# %% [markdown]
# Likelihood vs Probability
# Conditional Probability: P(outcome A∣given B)
# Probability: P(data∣model)
# Likelihood: L(model∣data)

# %% [markdown]
# Computing Likelihood
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# Likelihood from Probabilities

# %%
# Guess parameters
mu
_guess = np.mean(sample
_
distances)
sigma
_guess = np.std(sample
_
distances)
# For each sample point, compute a probability
probabilities = np.zeros(len(sample
_
distances))
for n, distance in enumerate(sample
_
distances):
probabilities[n] = gaussian
_
model(distance, mu=mu
_guess, sigma=sigma
_guess)
likelihood = np.product(probs)
loglikelihood = np.sum(np.log(probs))

# %% [markdown]
# Maximum Likelihood Estimation

# %%
# Create an array of mu guesses
low
_guess = sample
_
mean - 2*sample
_
stdev
high
_guess = sample
_
mean + 2*sample
_
stdev
mu
_guesses = np.linspace(low
_guess, high
_guess, 101)
# Compute the loglikelihood for each guess
loglikelihoods = np.zeros(len(mu
_guesses))
for n, mu
_guess in enumerate(mu
_guesses):
loglikelihoods[n] = compute
_
loglikelihood(sample
_
distances, mu=mu
_guess, sigma=sample
_
stdev)
# Find the best guess
max
_
loglikelihood = np.max(loglikelihoods)
best
_
mu = mu
_guesses[loglikelihoods == max
_
loglikelihood]

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Model Uncertainty and Sample Distributions

# %% [markdown]
# Population Unavailable
# ![image.png](attachment:image.png)

# %% [markdown]
# Sample as Population Model
# ![image.png](attachment:image.png)

# %% [markdown]
# Sample Statistic
# ![image.png](attachment:image.png)

# %% [markdown]
# Bootstrap Resampling
# ![image.png](attachment:image.png)

# %% [markdown]
# Resample Distribution
# ![image.png](attachment:image.png)

# %% [markdown]
# Bootstrap in Code

# %%
# Use sample as model for population
population
_
model = august
_
daily_
highs
_
for
_
2017
# Simulate repeated data acquisitions by resampling the "model"
for nr in range(num
_
resamples):
bootstrap_
sample = np.random.choice(population
_
model, size=resample
_
size, replace=True)
bootstrap_
means[nr] = np.mean(bootstrap_
sample)
# Compute the mean of the bootstrap resample distribution
estimate
_
temperature = np.mean(bootstrap_
means)
# Compute standard deviation of the bootstrap resample distribution
estimate
_
uncertainty = np.std(bootstrap_
means)

# %% [markdown]
# Replacement

# %%
# Define the sample of notes
sample = ['A'
,
'B'
,
'C'
,
'D'
,
'E'
,
'F'
,
'G']
# Replace = True, repeats are allowed
bootstrap_
sample = np.random.choice(sample, size=4, replace=True)
print(bootstrap_
sample)
C C F G

# %%
# Replace = False
bootstrap_
sample = np.random.choice(sample, size=4, replace=False)
print(bootstrap_
sample)
C G A F
# Replace = True, more lengths are allowed
bootstrap_
sample = np.random.choice(sample, size=16, replace=True)
print(bootstrap_
sample)
C C F G C G A E F D G B B A E C

# %% [markdown]
# ### Model Errors and Randomness

# %% [markdown]
# Types of Errors
# 1. Measurement error
# e.g.: broken sensor, wrongly recorded measurements
# 2. Sampling bias
# e.g: temperatures only from August, when days are hoest
# 3. Random chance

# %% [markdown]
# Null Hypothesis
# Question: Is our eect due a relationship or due to random chance?
# Answer: check the Null Hypothesis.

# %% [markdown]
# Ordered Data
# ![image.png](attachment:image.png)

# %% [markdown]
# Grouping Data
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
# Short Duration Group, mean = 5

# %% [markdown]
# Test Statistic

# %%
# Group into early and late times
group_
short = sample
_
distances[times < 5]
group_
long = sample
_
distances[times > 5]
# Resample distributions
resample
_
short = np.random.choice(group_
short, size=500, replace=True)
resample
_
long = np.random.choice(group_
long, size=500, replace=True)
# Test Statistic
test
_
statistic = resample
_
long - resample
_
short
# Effect size as mean of test statistic distribution
effect
_
size = np.mean(test
_
statistic)

# %% [markdown]
# Shuffle and Regrouping
# ![image.png](attachment:image.png)

# %% [markdown]
# Shuffling and Regrouping
# ![image.png](attachment:image.png)

# %% [markdown]
# Shuffle and Split

# %%
# Concatenate and Shuffle
shuffle
_
bucket = np.concatenate((group_
short, group_
long))
np.random.shuffle(shuffle
_
bucket)
# Split in the middle
slice
_
index = len(shuffle
_
bucket)//2
shuffled
_
half1 = shuffle
_
bucket[0:slice
_
index]
shuffled
_
half2 = shuffle
_
bucket[slice
_
index+1:]

# %% [markdown]
# Resample and Test Again

# %%
# Resample shuffled populations
shuffled
_
sample1 = np.random.choice(shuffled
_
half1, size=500, replace=True)
shuffled
_
sample2 = np.random.choice(shuffled
_
half2, size=500, replace=True)
# Recompute effect size
shuffled
_
test
_
statistic = shuffled
_
sample2 - shuffled
_
sample1
effect
_
size = np.mean(shuffled
_
test
_
statistic)

# %% [markdown]
# p-Value
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Model Conclusion

# %% [markdown]
# Exploring Linear Relationships
# - Motivation by Example Predictions
# - Visualizing Linear Relationships
# - Quantifying Linear Relationships

# %% [markdown]
# Building Linear Models
# - Model Parameters
# - Slope and Intercept
# - Taylor Series
# - Model Optimization
# - Least-Squares

# %% [markdown]
# Model Predictions
# - Modeling Real Data
# - Limitations and Pitfalls of Predictions
# - Goodness-of-Fit

# %% [markdown]
# Model Parameter Distributions
# - modeling parameters as probability distributions
# - samples, populations, and sampling
# - maximizing likelihood for parametric shapes
# - bootstrap resampling for arbitrary shapes
# - test statistics and p-values

# %% [markdown]
# # Generalized Linear Models in Python

# %% [markdown]
# ## Introduction to GLMs

# %% [markdown]
# ### Going beyond linear regression

# %% [markdown]
# ### How to build a GLM?

# %% [markdown]
# ### How to fit a GLM in Python?

# %% [markdown]
# ## Modeling Binary Data

# %% [markdown]
# ### Binaty data and logistic regression

# %% [markdown]
# ### Interpreting coefficients

# %% [markdown]
# ### Interpreting model inference

# %% [markdown]
# ### Computing and describing predictions

# %% [markdown]
# ## Modeling Count Data

# %% [markdown]
# ### Count data and Poisson distribution

# %% [markdown]
# ### Interpreting model fit

# %% [markdown]
# ### The Problem of Overdispersion

# %% [markdown]
# ### Plotting a regression model
