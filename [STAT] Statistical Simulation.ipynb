# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#STATISTICAL-SIMULATION-IN-PYTHON" data-toc-modified-id="STATISTICAL-SIMULATION-IN-PYTHON-1"><span class="toc-item-num">1&nbsp;&nbsp;</span><strong>STATISTICAL SIMULATION IN PYTHON</strong></a></span><ul class="toc-item"><li><span><a href="#Basics-of-randomness-&amp;-simulation" data-toc-modified-id="Basics-of-randomness-&amp;-simulation-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Basics of randomness &amp; simulation</a></span><ul class="toc-item"><li><span><a href="#Introduction-to-random-variables" data-toc-modified-id="Introduction-to-random-variables-1.1.1"><span class="toc-item-num">1.1.1&nbsp;&nbsp;</span>Introduction to random variables</a></span></li><li><span><a href="#Simulation-basics" data-toc-modified-id="Simulation-basics-1.1.2"><span class="toc-item-num">1.1.2&nbsp;&nbsp;</span>Simulation basics</a></span></li><li><span><a href="#Using-simulation-for-decision-making" data-toc-modified-id="Using-simulation-for-decision-making-1.1.3"><span class="toc-item-num">1.1.3&nbsp;&nbsp;</span>Using simulation for decision-making</a></span></li></ul></li><li><span><a href="#Probability-&amp;-data-generation-process" data-toc-modified-id="Probability-&amp;-data-generation-process-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Probability &amp; data generation process</a></span><ul class="toc-item"><li><span><a href="#Probability-basics" data-toc-modified-id="Probability-basics-1.2.1"><span class="toc-item-num">1.2.1&nbsp;&nbsp;</span>Probability basics</a></span></li><li><span><a href="#More-probability-concepts" data-toc-modified-id="More-probability-concepts-1.2.2"><span class="toc-item-num">1.2.2&nbsp;&nbsp;</span>More probability concepts</a></span></li><li><span><a href="#Data-generating-process" data-toc-modified-id="Data-generating-process-1.2.3"><span class="toc-item-num">1.2.3&nbsp;&nbsp;</span>Data generating process</a></span></li><li><span><a href="#eCommerce-Ad-Simulation" data-toc-modified-id="eCommerce-Ad-Simulation-1.2.4"><span class="toc-item-num">1.2.4&nbsp;&nbsp;</span>eCommerce Ad Simulation</a></span></li></ul></li><li><span><a href="#Resampling-methods" data-toc-modified-id="Resampling-methods-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>Resampling methods</a></span><ul class="toc-item"><li><span><a href="#Introduction-to-resampling-methods" data-toc-modified-id="Introduction-to-resampling-methods-1.3.1"><span class="toc-item-num">1.3.1&nbsp;&nbsp;</span>Introduction to resampling methods</a></span></li><li><span><a href="#Bootstrapping" data-toc-modified-id="Bootstrapping-1.3.2"><span class="toc-item-num">1.3.2&nbsp;&nbsp;</span>Bootstrapping</a></span></li><li><span><a href="#Jackknife-resampling" data-toc-modified-id="Jackknife-resampling-1.3.3"><span class="toc-item-num">1.3.3&nbsp;&nbsp;</span>Jackknife resampling</a></span></li><li><span><a href="#Permutation-testing" data-toc-modified-id="Permutation-testing-1.3.4"><span class="toc-item-num">1.3.4&nbsp;&nbsp;</span>Permutation testing</a></span></li></ul></li><li><span><a href="#Advanced-Applications-of-Simulation" data-toc-modified-id="Advanced-Applications-of-Simulation-1.4"><span class="toc-item-num">1.4&nbsp;&nbsp;</span>Advanced Applications of Simulation</a></span><ul class="toc-item"><li><span><a href="#Simulation-for-Business-Planning" data-toc-modified-id="Simulation-for-Business-Planning-1.4.1"><span class="toc-item-num">1.4.1&nbsp;&nbsp;</span>Simulation for Business Planning</a></span></li><li><span><a href="#Monte-Carlo-Integration" data-toc-modified-id="Monte-Carlo-Integration-1.4.2"><span class="toc-item-num">1.4.2&nbsp;&nbsp;</span>Monte Carlo Integration</a></span></li><li><span><a href="#Simulation-of-Power-Analysis" data-toc-modified-id="Simulation-of-Power-Analysis-1.4.3"><span class="toc-item-num">1.4.3&nbsp;&nbsp;</span>Simulation of Power Analysis</a></span></li><li><span><a href="#Applications-in-Finance" data-toc-modified-id="Applications-in-Finance-1.4.4"><span class="toc-item-num">1.4.4&nbsp;&nbsp;</span>Applications in Finance</a></span></li></ul></li></ul></li></ul></div>

# %% [markdown]
# # **STATISTICAL SIMULATION IN PYTHON**
# Tushar Shanker (Data Scientist - Uber, Airbnb, LinkedIn)

# %% [markdown]
# ## Basics of randomness & simulation

# %% [markdown]
# ### Introduction to random variables

# %% [markdown]
# - Topics covered
#   - Basics of randomness & simulation.
#   - Simulation & probability.
#   - Bootstrapping and resampling methods.
#   - Advanced applications of simulation.
#
# - Random variables: variables that can have multiple values, based on random chance
#   - Continuous Random Variables
#     - Infitely many possible values.
#     - e.g., Height / Weight
#
#   - Discrete Random Variables
#     - Finite set of possible values.
#     - e.g., Outcomes of a six-sided die
#
# - Probability distributions: how likely you are to obtain an outcome or a set of outcomes
#   - Continuous Probability Distributions: probability density function (intervals)
#   - Discrete Probability Distributions: probability Mass function (singlepoint or intervals)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import numpy as np
#FULL EXAMPLE 1 - introduction to np.random
help (np.random.choice)
#choice(a, size=None, replace=True, p=None)

# %%
#FULL EXAMPLE 2 - Poisson - average rate at which events occur

# Initialize seed and parameters
np.random.seed(123) 
lam, size_1, size_2 = 5, 3, 1000  

# Draw samples & calculate absolute difference between lambda and sample mean
samples_1 = np.random.poisson(lam, size_1)
samples_2 = np.random.poisson(lam, size_2)
answer_1 = abs(np.mean(samples_1)-lam)
answer_2 = abs(np.mean(samples_2)-lam) 

print("|Lambda - sample mean| with {} samples is {} and with {} samples is {}. ".format(size_1, answer_1, size_2, answer_2))
# Out:
# |Lambda - sample mean| with 3 samples is 0.33333333333333304 and with 1000 samples is 0.07699999999999996.

# %%
#FULL EXAMPLE 3 - Shuffing a deck of cards

# Shuffle the deck
np.random.shuffle(deck_of_cards)

# Print out the top three cards
card_choices_after_shuffle = deck_of_cards[0:3]
print(card_choices_after_shuffle)

# %% [markdown]
# ### Simulation basics

# %% [markdown]
# Simulations concepts
# - Framework for modeling real-world events and processes.
#   - Characterized by repeated random sampling (power of random variables to generate multiple outcomes).
#   - Gives us an approximate solution.
#   - Can help solve complex problems (prediction methods do not give a clean solution).

# %% [markdown]
# Simulation steps
# 1. Define possible outcomes for random variables
# 2. Assign probabilities
# 3. Define relationships between multiple random variables
#
# First three steps are the statistical model
# 4. Get multiple outcomes by repeated random sampling
# 5. Analyze sample outcomes

# %% [markdown]
# Simulation the dice game
# - Throw two dices and win if they show the same number
# - What we need:
#   - Steps 1 and 2: define outcome of the dice and its probability (identical probability distributions - uniform one)
#   - Step 3: relationship between the dices. Same number, we win, if not, we loose. Describing the model is the foundation.
#   - Step 4: multiple outcomes repeating random samplings

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
#FULL EXAMPLE 1 - throw 1 die
# Define die outcomes and probabilities
die, probabilities, throws = [1,2,3,4,5,6], [1/6,1/6,1/6,1/6,1/6,1/6], 1

# Use np.random.choice to throw the die once and record the outcome
outcome = np.random.choice(die, size=throws, p=probabilities)
print("Outcome of the throw: {}".format(outcome[0]))
# Out:
# Outcome of the throw: 4

# %%
# Initialize number of dice, simulate & record outcome
die, probabilities, num_dice = [1,2,3,4,5,6], [1/6, 1/6, 1/6, 1/6, 1/6, 1/6], 2
outcomes = np.random.choice(die, size=num_dice, p=probabilities) 

# Win if the two dice show the same number
if outcomes[0] == outcomes[1]: 
    answer = 'win' 
else:
    answer = 'lose'

print("The dice show {} and {}. You {}!".format(outcomes[0], outcomes[1], answer))
# Out:
# The dice show 2 and 6. You lose!

# %% [markdown]
# ### Using simulation for decision-making

# %% [markdown]
# Simulation workflow:
# - Steps 1 and 2: defining the outcome for random variables and assigning probabilities
# - Step 3: relationship between model parameters
# - Step 4: repeated samplings for variables A and B
# - Step 5: analyze outcomes

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# - If you change any input (such as probability distribution of B), evaluate output
# - Simulating a new set of outcomes
# - Outcomes: New B vs. Old B (changes the outcome significantly)
# - B should not have a particular stock in our portfolio (we can see how sensitivity our outcome is with B)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Change input to get desired output (change the C constant for example, so we can get the minimum value of the distribution as five)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Modify C and record outcomes

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Change input to get desired output (iteratively)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
#FULL EXAMPLE 1 - win a lotery with one ticket

# Pre-defined constant variables
lottery_ticket_cost, num_tickets, grand_prize = 10, 1000, 10000

# Probability of winning
chance_of_winning = 1/num_tickets

# Simulate a single drawing of the lottery
gains = [-lottery_ticket_cost, grand_prize-lottery_ticket_cost]
probability = [1-chance_of_winning, chance_of_winning]
outcome = np.random.choice(a=gains, size=1, p=probability, replace=True)

print("Outcome of one drawing of the lottery is {}".format(outcome))
# Out:
# Outcome of one drawing of the lottery is [-10]

# %%
#FULL EXAMPLE 2 - 2000 simulations

# Initialize size and simulate outcome
lottery_ticket_cost, num_tickets, grand_prize = 10, 1000, 10000
chance_of_winning = 1/num_tickets
size = 2000
payoffs = [-lottery_ticket_cost,grand_prize - lottery_ticket_cost]
probs = [1-chance_of_winning,chance_of_winning]

outcomes = np.random.choice(a=payoffs, size=size, p=probs, replace=True)

# Mean of outcomes.
answer = np.mean(outcomes)
print("Average payoff from {} simulations = {}".format(size, answer))
# Out:
# Average payoff from 2000 simulations = 10.0

# %%
#FULL EXAMPLE 3

# Initialize simulations and cost of ticket
sims, lottery_ticket_cost = 3000, 0

# Use a while loop to increment `lottery_ticket_cost` till average value of outcomes falls below zero
while 1:
    outcomes = np.random.choice([-lottery_ticket_cost, grand_prize-lottery_ticket_cost],
                 size=sims, p=[1-chance_of_winning, chance_of_winning], replace=True)
    if outcomes.mean() < 0:
        break
    else:
        lottery_ticket_cost += 1
answer = lottery_ticket_cost - 1

print("The highest price at which it makes sense to buy the ticket is {}".format(answer))
# Out:
# The highest price at which it makes sense to buy the ticket is 7

# %% [markdown]
# ## Probability & data generation process

# %% [markdown]
# ### Probability basics

# %% [markdown]
# Probability
# - Sample Space S: Set of all possible outcomes
# ![image.png](attachment:image.png)
# - Probability P (A): Likelihood of event A
#   - 0 ≤ P (A) ≤ 1
#   - P (S) = 1 eg. P (H) + P (T) = 1 #head and tail
# - For mutually exclusive events A and B:
#   - P (A ∩ B) = 0
#   - P (A ∪ B) = P (A) + P (B)
#
# Probability
# - P (A ∪ B) = P (A) + P (B) − P (A ∩ B)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Using Simulation for Probability Estimation
# Steps for Estimating Probability:
# 1. Construct sample space or population. (with all possible outcomes)
# 2. Determine how to simulate one outcome.
# 3. Determine rule for success.
# 4. Sample repeatedly and count successes.
# 5. Calculate frequency of successes as an estimate of probability.

# %% [markdown]
# ### More probability concepts

# %% [markdown]
# Conditional Probability

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# ### Data generating process

# %% [markdown]
# Simulation Steps
# 1. Dene Possible Outcomes for Random Variables.
# 2. Assign Probabilities.
# 3. Dene Relationships between Random Variables.

# %% [markdown]
# Data Generating Process
# ![image.png](attachment:image.png)

# %% [markdown]
# Cricket
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# ### eCommerce Ad Simulation

# %% [markdown]
# eCommerce Funnel
# ![image.png](attachment:image.png)

# %% [markdown]
# Signup Flow
# ![image.png](attachment:image.png)

# %% [markdown]
# Purchase Flow
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Resampling methods

# %% [markdown]
# ### Introduction to resampling methods

# %% [markdown]
# ### Bootstrapping

# %% [markdown]
# ### Jackknife resampling

# %% [markdown]
# ### Permutation testing

# %% [markdown]
# ## Advanced Applications of Simulation

# %% [markdown]
# ### Simulation for Business Planning

# %% [markdown]
# ### Monte Carlo Integration

# %% [markdown]
# ### Simulation of Power Analysis

# %% [markdown]
# ### Applications in Finance
